# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importation des fichiers de données et transformation en dataframe

# %%
from pathlib import Path

# On part du dossier où se trouve le notebook, puis on remonte d'un niveau pour atteindre la racine du projet.
root_path = Path.cwd().parent 

# 2. Définir le chemin vers le dossier des données
data_folder = root_path / "data/raws"

print(f"🔍 Recherche des données dans : {data_folder}")

# 3. Créer un dictionnaire pour stocker nos DataFrames
# Clé = nom du fichier, Valeur = DataFrame chargé
all_dataframes = {}

# 4. Vérifier si le dossier existe
if data_folder.exists() and data_folder.is_dir():
    
    # On cherche tous les fichiers finissant par .csv dans le dossier data
    csv_files = list(data_folder.glob("*.csv"))
    
    if not csv_files:
        print("⚠️ Aucun fichier CSV trouvé dans le dossier 'data'.")
    else:
        print(f"✅ {len(csv_files)} fichiers trouvés. Chargement en cours...")
        
        for file_path in csv_files:
            try:
                # On utilise le nom du fichier (sans l'extension) comme clé
                df_name = file_path.stem 
                
                # Chargement du CSV
                df = pd.read_csv(file_path)
                
                # Stockage dans notre dictionnaire
                all_dataframes[df_name] = df
                
                print(f"   👉 {file_path.name} chargé ({len(df)} lignes)")
                
            except Exception as e:
                print(f"   ❌ Erreur sur {file_path.name} : {e}")
                
        print("\n✨ Chargement terminé !")
else:
    print(f"❌ Le dossier '{data_folder}' est introuvable. Vérifie ton arborescence.")
# Out:
# 🔍 Recherche des données dans : c:\Users\johan\VS Code Wild 2\BRIEF_FAO_DataLab_Analyse_mondiale_de_la_sécurité_alimentaire\data\raws
# ✅ 5 fichiers trouvés. Chargement en cours...
#    👉 fr_animaux.csv chargé (37166 lignes)
#    👉 fr_céréales.csv chargé (891 lignes)
#    👉 fr_population.csv chargé (175 lignes)
#    👉 fr_sousalimentation.csv chargé (1020 lignes)
#    👉 fr_vegetaux.csv chargé (104871 lignes)
#
# ✨ Chargement terminé !

# %% [markdown]
# ### Analyse descriptive

# %%
print("👀 Inspection visuelle des premières lignes\n")
print("=" * 60)

for name, df in all_dataframes.items():
    print(f"📂 FICHIER : {name}")
    print(f"📏 Dimensions : {df.shape[0]} lignes, {df.shape[1]} colonnes")
    print("-" * 30)
    
    # Affichage des 5 premières lignes
    # On utilise display() pour une belle présentation dans le notebook
    display(df.head(10))
    
    print("\n" + "=" * 60 + "\n")
# Out:
# 👀 Inspection visuelle des premières lignes
#
# ============================================================
# 📂 FICHIER : fr_animaux
# 📏 Dimensions : 37166 lignes, 14 colonnes
# ------------------------------
#   Code Domaine                                            Domaine  Code zone  \
# 0         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 1         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 2         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 3         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 4         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 5         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 6         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 7         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 8         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 9         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
#
#           Zone  Code Élément  \
# 0  Afghanistan          5511
# 1  Afghanistan          5611
# 2  Afghanistan          5301
# 3  Afghanistan          5142
# 4  Afghanistan           645
# 5  Afghanistan           664
# 6  Afghanistan           674
# 7  Afghanistan           684
# 8  Afghanistan          5511
# 9  Afghanistan          5301
#
#                                              Élément  Code Produit  \
# 0                                         Production          2731
# 1                            Importations - Quantité          2731
# 2                           Disponibilité intérieure          2731
# 3                                         Nourriture          2731
# 4  Disponibilité alimentaire en quantité (kg/pers...          2731
# 5     Disponibilité alimentaire (Kcal/personne/jour)          2731
# 6  Disponibilité de protéines en quantité (g/pers...          2731
# 7  Disponibilité de matière grasse en quantité (g...          2731
# 8                                         Production          2732
# 9                           Disponibilité intérieure          2732
#
#                   Produit  Code année  Année               Unité  Valeur  \
# 0        Viande de Bovins        2013   2013  Milliers de tonnes  134.00
# 1        Viande de Bovins        2013   2013  Milliers de tonnes    6.00
# 2        Viande de Bovins        2013   2013  Milliers de tonnes  140.00
# 3        Viande de Bovins        2013   2013  Milliers de tonnes  140.00
# 4        Viande de Bovins        2013   2013                  kg    4.59
# 5        Viande de Bovins        2013   2013  Kcal/personne/jour   27.00
# 6        Viande de Bovins        2013   2013     g/personne/jour    1.89
# 7        Viande de Bovins        2013   2013     g/personne/jour    2.10
# 8  Viande d'Ovins/Caprins        2013   2013  Milliers de tonnes  150.00
# 9  Viande d'Ovins/Caprins        2013   2013  Milliers de tonnes  150.00
#
#   Symbole Description du Symbole
# 0       S  Données standardisées
# 1       S  Données standardisées
# 2       S  Données standardisées
# 3       S  Données standardisées
# 4      Fc        Donnée calculée
# 5      Fc        Donnée calculée
# 6      Fc        Donnée calculée
# 7      Fc        Donnée calculée
# 8       S  Données standardisées
# 9       S  Données standardisées
# ============================================================
#
# 📂 FICHIER : fr_céréales
# 📏 Dimensions : 891 lignes, 14 colonnes
# ------------------------------
#   Code Domaine                                            Domaine  Code zone  \
# 0         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 1         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 2         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 3         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 4         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 5         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        202
# 6         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        202
# 7         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        202
# 8         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        202
# 9         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        202
#
#              Zone  Code Élément     Élément  Code Produit           Produit  \
# 0     Afghanistan          5511  Production          2511               Blé
# 1     Afghanistan          5511  Production          2805  Riz (Eq Blanchi)
# 2     Afghanistan          5511  Production          2513              Orge
# 3     Afghanistan          5511  Production          2514              Maïs
# 4     Afghanistan          5511  Production          2517            Millet
# 5  Afrique du Sud          5511  Production          2511               Blé
# 6  Afrique du Sud          5511  Production          2805  Riz (Eq Blanchi)
# 7  Afrique du Sud          5511  Production          2513              Orge
# 8  Afrique du Sud          5511  Production          2514              Maïs
# 9  Afrique du Sud          5511  Production          2515            Seigle
#
#    Code année  Année               Unité  Valeur Symbole  \
# 0        2013   2013  Milliers de tonnes    5169       S
# 1        2013   2013  Milliers de tonnes     342       S
# 2        2013   2013  Milliers de tonnes     514       S
# 3        2013   2013  Milliers de tonnes     312       S
# 4        2013   2013  Milliers de tonnes      13       S
# 5        2013   2013  Milliers de tonnes    1870       S
# 6        2013   2013  Milliers de tonnes       3       S
# 7        2013   2013  Milliers de tonnes     268       S
# 8        2013   2013  Milliers de tonnes   11811       S
# 9        2013   2013  Milliers de tonnes       2       S
#
#   Description du Symbole
# 0  Données standardisées
# 1  Données standardisées
# 2  Données standardisées
# 3  Données standardisées
# 4  Données standardisées
# 5  Données standardisées
# 6  Données standardisées
# 7  Données standardisées
# 8  Données standardisées
# 9  Données standardisées
# ============================================================
#
# 📂 FICHIER : fr_population
# 📏 Dimensions : 175 lignes, 14 colonnes
# ------------------------------
#   Code Domaine                                            Domaine  Code zone  \
# 0         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 1         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        202
# 2         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          3
# 3         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          4
# 4         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...         79
# 5         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          7
# 6         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          8
# 7         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...        194
# 8         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          9
# 9         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          1
#
#                  Zone  Code Élément            Élément  Code Produit  \
# 0         Afghanistan           511  Population totale          2501
# 1      Afrique du Sud           511  Population totale          2501
# 2             Albanie           511  Population totale          2501
# 3             Algérie           511  Population totale          2501
# 4           Allemagne           511  Population totale          2501
# 5              Angola           511  Population totale          2501
# 6  Antigua-et-Barbuda           511  Population totale          2501
# 7     Arabie saoudite           511  Population totale          2501
# 8           Argentine           511  Population totale          2501
# 9             Arménie           511  Population totale          2501
#
#       Produit  Code année  Année           Unité  Valeur Symbole  \
# 0  Population        2013   2013  1000 personnes   30552     NaN
# 1  Population        2013   2013  1000 personnes   52776     NaN
# 2  Population        2013   2013  1000 personnes    3173     NaN
# 3  Population        2013   2013  1000 personnes   39208     NaN
# 4  Population        2013   2013  1000 personnes   82727     NaN
# 5  Population        2013   2013  1000 personnes   21472     NaN
# 6  Population        2013   2013  1000 personnes      90     NaN
# 7  Population        2013   2013  1000 personnes   28829     NaN
# 8  Population        2013   2013  1000 personnes   41446     NaN
# 9  Population        2013   2013  1000 personnes    2977     NaN
#
#   Description du Symbole
# 0      Donnée officielle
# 1      Donnée officielle
# 2      Donnée officielle
# 3      Donnée officielle
# 4      Donnée officielle
# 5      Donnée officielle
# 6      Donnée officielle
# 7      Donnée officielle
# 8      Donnée officielle
# 9      Donnée officielle
# ============================================================
#
# 📂 FICHIER : fr_sousalimentation
# 📏 Dimensions : 1020 lignes, 15 colonnes
# ------------------------------
#   Code Domaine                             Domaine  Code zone            Zone  \
# 0           FS  Données de la sécurité alimentaire          2     Afghanistan
# 1           FS  Données de la sécurité alimentaire          2     Afghanistan
# 2           FS  Données de la sécurité alimentaire          2     Afghanistan
# 3           FS  Données de la sécurité alimentaire          2     Afghanistan
# 4           FS  Données de la sécurité alimentaire          2     Afghanistan
# 5           FS  Données de la sécurité alimentaire        202  Afrique du Sud
# 6           FS  Données de la sécurité alimentaire        202  Afrique du Sud
# 7           FS  Données de la sécurité alimentaire        202  Afrique du Sud
# 8           FS  Données de la sécurité alimentaire        202  Afrique du Sud
# 9           FS  Données de la sécurité alimentaire        202  Afrique du Sud
#
#    Code Élément Élément  Code Produit  \
# 0          6132  Valeur        210011
# 1          6132  Valeur        210011
# 2          6132  Valeur        210011
# 3          6132  Valeur        210011
# 4          6132  Valeur        210011
# 5          6132  Valeur        210011
# 6          6132  Valeur        210011
# 7          6132  Valeur        210011
# 8          6132  Valeur        210011
# 9          6132  Valeur        210011
#
#                                              Produit  Code année      Année  \
# 0  Nombre de personnes sous-alimentées (millions)...    20122014  2012-2014
# 1  Nombre de personnes sous-alimentées (millions)...    20132015  2013-2015
# 2  Nombre de personnes sous-alimentées (millions)...    20142016  2014-2016
# 3  Nombre de personnes sous-alimentées (millions)...    20152017  2015-2017
# 4  Nombre de personnes sous-alimentées (millions)...    20162018  2016-2018
# 5  Nombre de personnes sous-alimentées (millions)...    20122014  2012-2014
# 6  Nombre de personnes sous-alimentées (millions)...    20132015  2013-2015
# 7  Nombre de personnes sous-alimentées (millions)...    20142016  2014-2016
# 8  Nombre de personnes sous-alimentées (millions)...    20152017  2015-2017
# 9  Nombre de personnes sous-alimentées (millions)...    20162018  2016-2018
#
#       Unité Valeur Symbole Description du Symbole  Note
# 0  millions    7.9       F         Estimation FAO   NaN
# 1  millions    8.8       F         Estimation FAO   NaN
# 2  millions    9.6       F         Estimation FAO   NaN
# 3  millions   10.2       F         Estimation FAO   NaN
# 4  millions   10.6       F         Estimation FAO   NaN
# 5  millions    2.6       F         Estimation FAO   NaN
# 6  millions    2.8       F         Estimation FAO   NaN
# 7  millions    3.2       F         Estimation FAO   NaN
# 8  millions    3.4       F         Estimation FAO   NaN
# 9  millions    3.5       F         Estimation FAO   NaN
# ============================================================
#
# 📂 FICHIER : fr_vegetaux
# 📏 Dimensions : 104871 lignes, 14 colonnes
# ------------------------------
#   Code Domaine                                            Domaine  Code zone  \
# 0         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 1         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 2         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 3         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 4         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 5         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 6         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 7         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 8         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
# 9         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...          2
#
#           Zone  Code Élément  \
# 0  Afghanistan          5511
# 1  Afghanistan          5611
# 2  Afghanistan          5072
# 3  Afghanistan          5301
# 4  Afghanistan          5527
# 5  Afghanistan          5123
# 6  Afghanistan          5142
# 7  Afghanistan           645
# 8  Afghanistan           664
# 9  Afghanistan           674
#
#                                              Élément  Code Produit Produit  \
# 0                                         Production          2511     Blé
# 1                            Importations - Quantité          2511     Blé
# 2                                 Variation de stock          2511     Blé
# 3                           Disponibilité intérieure          2511     Blé
# 4                                           Semences          2511     Blé
# 5                                             Pertes          2511     Blé
# 6                                         Nourriture          2511     Blé
# 7  Disponibilité alimentaire en quantité (kg/pers...          2511     Blé
# 8     Disponibilité alimentaire (Kcal/personne/jour)          2511     Blé
# 9  Disponibilité de protéines en quantité (g/pers...          2511     Blé
#
#    Code année  Année               Unité   Valeur Symbole  \
# 0        2013   2013  Milliers de tonnes  5169.00       S
# 1        2013   2013  Milliers de tonnes  1173.00       S
# 2        2013   2013  Milliers de tonnes  -350.00       S
# 3        2013   2013  Milliers de tonnes  5992.00       S
# 4        2013   2013  Milliers de tonnes   322.00       S
# 5        2013   2013  Milliers de tonnes   775.00       S
# 6        2013   2013  Milliers de tonnes  4895.00       S
# 7        2013   2013                  kg   160.23      Fc
# 8        2013   2013  Kcal/personne/jour  1369.00      Fc
# 9        2013   2013     g/personne/jour    36.91      Fc
#
#   Description du Symbole
# 0  Données standardisées
# 1  Données standardisées
# 2  Données standardisées
# 3  Données standardisées
# 4  Données standardisées
# 5  Données standardisées
# 6  Données standardisées
# 7        Donnée calculée
# 8        Donnée calculée
# 9        Donnée calculée
# ============================================================

# %%
print("🔍 Rapport de Qualité des Données (Taux de complétude)\n")
print("-" * 60)

# On parcourt notre dictionnaire de DataFrames
for name, df in all_dataframes.items():
    total_rows = len(df)
    
    print(f"📊 FICHIER : {name} ({total_rows} lignes)")
    print("-" * 30)
    
    # On calcule les valeurs manquantes pour chaque colonne
    null_counts = df.isnull().sum()
    
    for col in null_counts.index:
        null_count = null_counts[col]
        
        if total_rows > 0:
            # Calcul du pourcentage de données manquantes
            pct_missing = (null_count / total_rows) * 100
            
            # On prépare un affichage propre
            # Si le manque est faible, on affiche en vert (symboliquement)
            # Si le manque est élevé (> 5%), on l'alerte
            status = "✅ OK" if pct_missing < 5 else "⚠️ ALERTE"
            
            print(f"  [{status}] {col:20} : {null_count:>6} manquantes ({pct_missing:>5.2f}%)")
        else:
            print((f"  ❌ Fichier vide pour la colonne {col}"))
            
    print("\n" + "="*60 + "\n")
# Out:
# 🔍 Rapport de Qualité des Données (Taux de complétude)
#
# ------------------------------------------------------------
# 📊 FICHIER : fr_animaux (37166 lignes)
# ------------------------------
#   [✅ OK] Code Domaine         :      0 manquantes ( 0.00%)
#   [✅ OK] Domaine              :      0 manquantes ( 0.00%)
#   [✅ OK] Code zone            :      0 manquantes ( 0.00%)
#   [✅ OK] Zone                 :      0 manquantes ( 0.00%)
#   [✅ OK] Code Élément         :      0 manquantes ( 0.00%)
#   [✅ OK] Élément              :      0 manquantes ( 0.00%)
#   [✅ OK] Code Produit         :      0 manquantes ( 0.00%)
#   [✅ OK] Produit              :      0 manquantes ( 0.00%)
#   [✅ OK] Code année           :      0 manquantes ( 0.00%)
#   [✅ OK] Année                :      0 manquantes ( 0.00%)
#   [✅ OK] Unité                :      0 manquantes ( 0.00%)
#   [✅ OK] Valeur               :      0 manquantes ( 0.00%)
#   [✅ OK] Symbole              :      0 manquantes ( 0.00%)
#   [✅ OK] Description du Symbole :      0 manquantes ( 0.00%)
#
# ============================================================
#
# 📊 FICHIER : fr_céréales (891 lignes)
# ------------------------------
#   [✅ OK] Code Domaine         :      0 manquantes ( 0.00%)
#   [✅ OK] Domaine              :      0 manquantes ( 0.00%)
#   [✅ OK] Code zone            :      0 manquantes ( 0.00%)
#   [✅ OK] Zone                 :      0 manquantes ( 0.00%)
#   [✅ OK] Code Élément         :      0 manquantes ( 0.00%)
#   [✅ OK] Élément              :      0 manquantes ( 0.00%)
#   [✅ OK] Code Produit         :      0 manquantes ( 0.00%)
#   [✅ OK] Produit              :      0 manquantes ( 0.00%)
#   [✅ OK] Code année           :      0 manquantes ( 0.00%)
#   [✅ OK] Année                :      0 manquantes ( 0.00%)
#   [✅ OK] Unité                :      0 manquantes ( 0.00%)
#   [✅ OK] Valeur               :      0 manquantes ( 0.00%)
#   [✅ OK] Symbole              :      0 manquantes ( 0.00%)
#   [✅ OK] Description du Symbole :      0 manquantes ( 0.00%)
#
# ============================================================
#
# 📊 FICHIER : fr_population (175 lignes)
# ------------------------------
#   [✅ OK] Code Domaine         :      0 manquantes ( 0.00%)
#   [✅ OK] Domaine              :      0 manquantes ( 0.00%)
#   [✅ OK] Code zone            :      0 manquantes ( 0.00%)
#   [✅ OK] Zone                 :      0 manquantes ( 0.00%)
#   [✅ OK] Code Élément         :      0 manquantes ( 0.00%)
#   [✅ OK] Élément              :      0 manquantes ( 0.00%)
#   [✅ OK] Code Produit         :      0 manquantes ( 0.00%)
#   [✅ OK] Produit              :      0 manquantes ( 0.00%)
#   [✅ OK] Code année           :      0 manquantes ( 0.00%)
#   [✅ OK] Année                :      0 manquantes ( 0.00%)
#   [✅ OK] Unité                :      0 manquantes ( 0.00%)
#   [✅ OK] Valeur               :      0 manquantes ( 0.00%)
#   [⚠️ ALERTE] Symbole              :    174 manquantes (99.43%)
#   [✅ OK] Description du Symbole :      0 manquantes ( 0.00%)
#
# ============================================================
#
# 📊 FICHIER : fr_sousalimentation (1020 lignes)
# ------------------------------
#   [✅ OK] Code Domaine         :      0 manquantes ( 0.00%)
#   [✅ OK] Domaine              :      0 manquantes ( 0.00%)
#   [✅ OK] Code zone            :      0 manquantes ( 0.00%)
#   [✅ OK] Zone                 :      0 manquantes ( 0.00%)
#   [✅ OK] Code Élément         :      0 manquantes ( 0.00%)
#   [✅ OK] Élément              :      0 manquantes ( 0.00%)
#   [✅ OK] Code Produit         :      0 manquantes ( 0.00%)
#   [✅ OK] Produit              :      0 manquantes ( 0.00%)
#   [✅ OK] Code année           :      0 manquantes ( 0.00%)
#   [✅ OK] Année                :      0 manquantes ( 0.00%)
#   [✅ OK] Unité                :      0 manquantes ( 0.00%)
#   [⚠️ ALERTE] Valeur               :    415 manquantes (40.69%)
#   [✅ OK] Symbole              :      0 manquantes ( 0.00%)
#   [✅ OK] Description du Symbole :      0 manquantes ( 0.00%)
#   [⚠️ ALERTE] Note                 :   1020 manquantes (100.00%)
#
# ============================================================
#
# 📊 FICHIER : fr_vegetaux (104871 lignes)
# ------------------------------
#   [✅ OK] Code Domaine         :      0 manquantes ( 0.00%)
#   [✅ OK] Domaine              :      0 manquantes ( 0.00%)
#   [✅ OK] Code zone            :      0 manquantes ( 0.00%)
#   [✅ OK] Zone                 :      0 manquantes ( 0.00%)
#   [✅ OK] Code Élément         :      0 manquantes ( 0.00%)
#   [✅ OK] Élément              :      0 manquantes ( 0.00%)
#   [✅ OK] Code Produit         :      0 manquantes ( 0.00%)
#   [✅ OK] Produit              :      0 manquantes ( 0.00%)
#   [✅ OK] Code année           :      0 manquantes ( 0.00%)
#   [✅ OK] Année                :      0 manquantes ( 0.00%)
#   [✅ OK] Unité                :      0 manquantes ( 0.00%)
#   [✅ OK] Valeur               :      0 manquantes ( 0.00%)
#   [✅ OK] Symbole              :      0 manquantes ( 0.00%)
#   [✅ OK] Description du Symbole :      0 manquantes ( 0.00%)
#
# ============================================================

# %% [markdown]
# Certaines colonnes sont très peu remplies voire complètement vides.
# Je supprimerai les colonnes 'symbole' de fr_population et 'note' de fr_sousalimentation.
# j'investiguerai sur la colonne 'Valeur' de fr_sousalimentation pour juger de l'intéret de cette colonne qui présente 40% de valeurs manquantes.

# %%
print("🔍 Rapport de Qualité des Données (Doublons)\n")
print("-" * 60)

for name, df in all_dataframes.items():
    total_rows = len(df)
    
    # --- PARTIE 1 : Vérification des doublons parfaits ---
    duplicate_count = df.duplicated().sum()
    
    print(f"📊 FICHIER : {name} ({total_rows} lignes)")
    print(f"  [!] Doublons parfaits trouvés : {duplicate_count}")
# Out:
# 🔍 Rapport de Qualité des Données (Doublons)
#
# ------------------------------------------------------------
# 📊 FICHIER : fr_animaux (37166 lignes)
#   [!] Doublons parfaits trouvés : 0
# 📊 FICHIER : fr_céréales (891 lignes)
#   [!] Doublons parfaits trouvés : 0
# 📊 FICHIER : fr_population (175 lignes)
#   [!] Doublons parfaits trouvés : 0
# 📊 FICHIER : fr_sousalimentation (1020 lignes)
#   [!] Doublons parfaits trouvés : 0
# 📊 FICHIER : fr_vegetaux (104871 lignes)
#   [!] Doublons parfaits trouvés : 0

# %% [markdown]
# Aucun doublon parfait
# En fonction des données regardées, nous analyserons plus en détail les éventuelles lignes doublées partiellement

# %%
print("🔍 Rapport de Qualité des Données (Dtypes)\n")
print("-" * 60)

for name, df in all_dataframes.items():
    print(f"📊 FICHIER : {name}")
    print(f"  Total colonnes : {len(df.columns)}")
    print("-" * 30)
    
    # On récupère les types et on crée un petit tableau récapitulatif
    dtype_info = []
    for col, dtype in df.dtypes.items():
        # On compte combien de valeurs ne sont PAS nulles pour voir la réalité du type
        non_null_count = df[col].count()
        dtype_info.append({
            "Colonne": col,
            "Type actuel": dtype,
  			"Valeurs non-nulles": non_null_count
        })
    
    # Création d'un DataFrame de diagnostic pour un affichage propre
    df_diag = pd.DataFrame(dtype_info)
    
    # On affiche le tableau de diagnostic
    display(df_diag)
    
    # Alerte spécifique : On cherche les colonnes numériques qui sont en type 'object'
    # (C'est souvent là que se cachent les erreurs de lecture)
    numeric_as_object = df_diag[(df_diag['Type actuel'] == 'object') & 
                                (df_diag['Colonne'].str.contains('Valeur|Année|Code', case=False, na=False))]
    
    if not numeric_as_object.empty:
        print(f"  ⚠️ ALERTE : Colonnes numériques potentiellement mal typées :")
        for _, row in numeric_as_object.iterrows():
            print(f"     👉 {row['Colonne']} est en type '{row['Type actuel']}'")
    else:
        print("  ✅ Aucun problème de type numérique détecté.")
        
    print("\n" + "="*60 + "\n")
# Out:
# 🔍 Rapport de Qualité des Données (Dtypes)
#
# ------------------------------------------------------------
# 📊 FICHIER : fr_animaux
#   Total colonnes : 14
# ------------------------------
#                    Colonne Type actuel  Valeurs non-nulles
# 0             Code Domaine         str               37166
# 1                  Domaine         str               37166
# 2                Code zone       int64               37166
# 3                     Zone         str               37166
# 4             Code Élément       int64               37166
# 5                  Élément         str               37166
# 6             Code Produit       int64               37166
# 7                  Produit         str               37166
# 8               Code année       int64               37166
# 9                    Année       int64               37166
# 10                   Unité         str               37166
# 11                  Valeur     float64               37166
# 12                 Symbole         str               37166
# 13  Description du Symbole         str               37166
#   ✅ Aucun problème de type numérique détecté.
#
# ============================================================
#
# 📊 FICHIER : fr_céréales
#   Total colonnes : 14
# ------------------------------
#                    Colonne Type actuel  Valeurs non-nulles
# 0             Code Domaine         str                 891
# 1                  Domaine         str                 891
# 2                Code zone       int64                 891
# 3                     Zone         str                 891
# 4             Code Élément       int64                 891
# 5                  Élément         str                 891
# 6             Code Produit       int64                 891
# 7                  Produit         str                 891
# 8               Code année       int64                 891
# 9                    Année       int64                 891
# 10                   Unité         str                 891
# 11                  Valeur       int64                 891
# 12                 Symbole         str                 891
# 13  Description du Symbole         str                 891
#   ✅ Aucun problème de type numérique détecté.
#
# ============================================================
#
# 📊 FICHIER : fr_population
#   Total colonnes : 14
# ------------------------------
#                    Colonne Type actuel  Valeurs non-nulles
# 0             Code Domaine         str                 175
# 1                  Domaine         str                 175
# 2                Code zone       int64                 175
# 3                     Zone         str                 175
# 4             Code Élément       int64                 175
# 5                  Élément         str                 175
# 6             Code Produit       int64                 175
# 7                  Produit         str                 175
# 8               Code année       int64                 175
# 9                    Année       int64                 175
# 10                   Unité         str                 175
# 11                  Valeur       int64                 175
# 12                 Symbole         str                   1
# 13  Description du Symbole         str                 175
#   ✅ Aucun problème de type numérique détecté.
#
# ============================================================
#
# 📊 FICHIER : fr_sousalimentation
#   Total colonnes : 15
# ------------------------------
#                    Colonne Type actuel  Valeurs non-nulles
# 0             Code Domaine         str                1020
# 1                  Domaine         str                1020
# 2                Code zone       int64                1020
# 3                     Zone         str                1020
# 4             Code Élément       int64                1020
# 5                  Élément         str                1020
# 6             Code Produit       int64                1020
# 7                  Produit         str                1020
# 8               Code année       int64                1020
# 9                    Année         str                1020
# 10                   Unité         str                1020
# 11                  Valeur         str                 605
# 12                 Symbole         str                1020
# 13  Description du Symbole         str                1020
# 14                    Note     float64                   0
#   ✅ Aucun problème de type numérique détecté.
#
# ============================================================
#
# 📊 FICHIER : fr_vegetaux
#   Total colonnes : 14
# ------------------------------
#                    Colonne Type actuel  Valeurs non-nulles
# 0             Code Domaine         str              104871
# 1                  Domaine         str              104871
# 2                Code zone       int64              104871
# 3                     Zone         str              104871
# 4             Code Élément       int64              104871
# 5                  Élément         str              104871
# 6             Code Produit       int64              104871
# 7                  Produit         str              104871
# 8               Code année       int64              104871
# 9                    Année       int64              104871
# 10                   Unité         str              104871
# 11                  Valeur     float64              104871
# 12                 Symbole         str              104871
# 13  Description du Symbole         str              104871
#   ✅ Aucun problème de type numérique détecté.
#
# ============================================================

# %% [markdown]
# Les types des colonnes sont tous corrects

# %%
print("📊 Analyse descriptive des distributions\n")
print("=" * 60)

for name, df in all_dataframes.items():
    print(f"📂 FICHIER : {name}")
    print("-" * 30)
    
    # On sélectionne uniquement les colonnes numériques pour le describe
    df_numeric = df.select_dtypes(include=['number'])
    
    if df_numeric.empty:
        print("  ℹ️ Pas de colonnes numériques dans ce fichier.")
    else:
        # Le describe() avec les statistiques clés
        stats = df_numeric.describe().T  # .T pour transposer et avoir un tableau lisible
        
        # On ajoute la variance pour voir l'étalement des données
        stats['variance'] = df_numeric.var()
        
        # On affiche le résultat
        display(stats[['count', 'mean', 'std', 'variance', 'min', '50%', 'max']])
        
        print("\n  💡 Note d'analyse :")
        for col in df_numeric.columns:
            col_min = df_arg_min = df_numeric[col].min()
            col_max = df_numeric[col].max()
            col_mean = df_numeric[col].mean()
            
            # Si la moyenne est très loin de la médiane (50%), il y a un déséquilibre
            if abs(col_mean - df_numeric[col].median()) > (df_numeric[col].std() * 1):
                print(f"     ⚠️ Attention sur '{col}' : La moyenne et la médiane sont très décalées. Présence probable d'asymétrie.")

    print("\n" + "=" * 60 + "\n")
# Out:
# 📊 Analyse descriptive des distributions
#
# ============================================================
# 📂 FICHIER : fr_animaux
# ------------------------------
#                 count         mean          std      variance     min     50%  \
# Code zone     37166.0   126.800839    74.767139  5.590125e+03     1.0   121.0
# Code Élément  37166.0  3511.032718  2332.283315  5.439545e+06   645.0  5142.0
# Code Produit  37166.0  2758.421191    27.454449  7.537468e+02  2731.0  2762.0
# Code année    37166.0  2013.000000     0.000000  0.000000e+00  2013.0  2013.0
# Année         37166.0  2013.000000     0.000000  0.000000e+00  2013.0  2013.0
# Valeur        37166.0   148.291647  1933.728473  3.739306e+06 -1368.0     1.0
#
#                    max
# Code zone        351.0
# Code Élément    5911.0
# Code Produit    2848.0
# Code année      2013.0
# Année           2013.0
# Valeur        135600.0
#   💡 Note d'analyse :
#
# ============================================================
#
# 📂 FICHIER : fr_céréales
# ------------------------------
#               count         mean           std      variance     min     50%  \
# Code zone     891.0   130.005612     74.807040  5.596093e+03     1.0   129.0
# Code Élément  891.0  5511.000000      0.000000  0.000000e+00  5511.0  5511.0
# Code Produit  891.0  2551.648709     96.152834  9.245367e+03  2511.0  2516.0
# Code année    891.0  2013.000000      0.000000  0.000000e+00  2013.0  2013.0
# Année         891.0  2013.000000      0.000000  0.000000e+00  2013.0  2013.0
# Valeur        891.0  2832.037037  16786.590126  2.817896e+08     0.0    95.0
#
#                    max
# Code zone        276.0
# Code Élément    5511.0
# Code Produit    2805.0
# Code année      2013.0
# Année           2013.0
# Valeur        353699.0
#   💡 Note d'analyse :
#
# ============================================================
#
# 📂 FICHIER : fr_population
# ------------------------------
#               count      mean            std      variance     min     50%  \
# Code zone     175.0    126.72      75.168519  5.650306e+03     1.0   121.0
# Code Élément  175.0    511.00       0.000000  0.000000e+00   511.0   511.0
# Code Produit  175.0   2501.00       0.000000  0.000000e+00  2501.0  2501.0
# Code année    175.0   2013.00       0.000000  0.000000e+00  2013.0  2013.0
# Année         175.0   2013.00       0.000000  0.000000e+00  2013.0  2013.0
# Valeur        175.0  48079.96  178632.742203  3.190966e+10    54.0  9413.0
#
#                     max
# Code zone         351.0
# Code Élément      511.0
# Code Produit     2501.0
# Code année       2013.0
# Année            2013.0
# Valeur        1416667.0
#   💡 Note d'analyse :
#
# ============================================================
#
# 📂 FICHIER : fr_sousalimentation
# ------------------------------
#                count          mean           std      variance         min  \
# Code zone     1020.0  1.292647e+02     76.615019  5.869861e+03         1.0
# Code Élément  1020.0  6.132000e+03      0.000000  0.000000e+00      6132.0
# Code Produit  1020.0  2.100110e+05      0.000000  0.000000e+00    210011.0
# Code année    1020.0  2.014202e+07  14150.488052  2.002363e+08  20122014.0
# Note             0.0           NaN           NaN           NaN         NaN
#
#                      50%         max
# Code zone          127.5       351.0
# Code Élément      6132.0      6132.0
# Code Produit    210011.0    210011.0
# Code année    20142016.0  20162018.0
# Note                 NaN         NaN
#   💡 Note d'analyse :
#
# ============================================================
#
# 📂 FICHIER : fr_vegetaux
# ------------------------------
#                  count         mean          std      variance      min  \
# Code zone     104871.0   127.694682    75.423255  5.688667e+03      1.0
# Code Élément  104871.0  3728.248429  2276.474811  5.182338e+06    645.0
# Code Produit  104871.0  2587.470998    61.107727  3.734154e+03   2511.0
# Code année    104871.0  2013.000000     0.000000  0.000000e+00   2013.0
# Année         104871.0  2013.000000     0.000000  0.000000e+00   2013.0
# Valeur        104871.0   321.271016  6395.039684  4.089653e+07 -39863.0
#
#                  50%       max
# Code zone      121.0     351.0
# Code Élément  5142.0    5911.0
# Code Produit  2575.0    2899.0
# Code année    2013.0    2013.0
# Année         2013.0    2013.0
# Valeur           1.0  739267.0
#   💡 Note d'analyse :
#
# ============================================================

# %% [markdown]
# fr_vegetaux contient des nombres négatifs dans la colonne 'valeur', il faut s'assurer de la vraisemblance de cette donnée
